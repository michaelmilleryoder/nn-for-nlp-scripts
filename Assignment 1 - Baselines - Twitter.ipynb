# %%
# %matplotlib inline

import itertools
import spacy
import pickle

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import keras.backend as K
import tensorflow as tf

from collections import defaultdict

from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import Sequential
from keras.layers import LSTM, Dense, Bidirectional, Embedding, Dropout, Reshape, TimeDistributed
from keras.utils import to_categorical, plot_model

from keras_tqdm import TQDMNotebookCallback, TQDMCallback

from pprint import pprint

from scipy import stats
from sklearn.metrics import cohen_kappa_score, accuracy_score, classification_report
from sklearn.metrics import precision_recall_fscore_support 
from sklearn.model_selection import StratifiedShuffleSplit, ShuffleSplit

from tqdm import tqdm

# %%
TWITTER_DATA_FILEPATH = '/home/james/corpora/twitter/trec2011_with_hashtags.pkl'
TUMBLR_DATA_FILEPATH = '/home/james/corpora/tumblr/halfday_text.pkl'

# %%
# Email Settings
import smtplib

wherefrom = 'j.m.fiacco@gmail.com'
whereto = '6037323260@msg.fi.google.com'
gmail_pw = 'thdqhntcjnqglhxk'

def send_text(text='Hello World!'):
    try:
        server = smtplib.SMTP("smtp.gmail.com", 587)
        server.ehlo()
        server.starttls()
        server.login(wherefrom, gmail_pw)
        ret = server.sendmail(wherefrom, whereto, ' '.join(['[[ASSIGNMENT]]', text]))
        server.quit()
        print ('Messsage sent.')
    except:
        print ('Message failed.')

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Twitter

# %%
twitter_data = pd.read_pickle(TWITTER_DATA_FILEPATH)
twitter_data
# Out:
#                                                       text             id_str  \
# 0        #imSorry. Kasi hindi ko masuklian pagmamahal k...  31334887931777024
# 1        RT @she3sha3y: #Jan25 #Egypt "not baradei, not...  31334648130830336
# 2        #buik #barutahu kalo sebelum cinta fitri di pu...  31334897025024000
# 3        @1DPaynettes #Twitition @onedirection to gig i...  31334903031267328
# 4          #SS3SG Eunhyuk !!! <3 http://twitpic.com/3uhp5y  31334401195380736
# 5        From me too...RT @archanavijaya: Its sooo nice...  31334910400663552
# 6        @fernando_x Resumindo: #jogojusto fail #saraiv...  31334915085697024
# 7        Parketpolitie int 750 euro aan openstaande boe...  31334919284195328
# 8        [Update] #SS3SG Shake It Up http://yfrog.com/h...  31334930269081601
# 9                                   #anispa #joqr スフィアきた！！  31334948820484096
# 10       中間発表でコメントをもらいます。 ( #bhopal_march live at http:...  31334954814148608
# 11       @Jones_Drew32 man I'm in cali too and I'm up t...  31334956114378752
# 12              Tapi sampai kapan gue harus nunggu lo #CCS  31334965459292160
# 13                        @edgarfong @ontobelli #Chale ._.  31334971327127553
# 14       "Quando desisti de perseguir a felicidade, ela...  31334972828680192
# 15       Daleeeeeeeem » "Banyak orang ngaku beriman, pa...  31334974913249280
# 16                     FSきたあああああああああああああああああ #agqr #anispa  31334978520350720
# 17       Baterista do U2 é condenado no Brasil. http://...  31334350448496640
# 18            É isso aii @CHRlSROCK ... #congratulations..  31334993997340672
# 19       RT @chip528_dgs: RT @keraidayo RT @RiinaKw RT ...  31334998996946944
# 20       Start Dealing with Critics and Criticism Right...  31335002142670850
# 21       RT @DonghaeBiased: [Update] #SS3SG Shake It Up...  31335009109417984
# 22       Cell phone service back on in #Egypt - RIA Nov...  31335013173698560
# 23       "Bringing King to China" http://bit.ly/eErpxw ...  31335016340389888
# 24       Today @MacMiller wishes that he was #somewhere...  31335018622095361
# 25       Comment: Les premiers spectateurs ... #photwi ...  31335018781474816
# 26                    Phones off, going on the planee #pow  31335030374535168
# 27       Oxford today for #Vols game? Bracelet @gabgirl...  31335032371027968
# 28       #FreebieFriday Retweet & follow @washbag_com f...  31335041158094848
# 29       tak peduli RT @AfgJember: #TebakLaguAfgan 8 : ...  31335041766260736
# ...                                                    ...                ...
# 1237990  #civ2010 Si LG est meurt financièrement et aya...  31338398736195584
# 1237991                                   #nw orang tempur  31338400309055488
# 1237992  LOOL adorable XD RT @amna_h: #WhenIWasLittle I...  31338416842997760
# 1237993  RT Al Jazeera: reports that Ahmad Ezz tried to...  31338421284773888
# 1237994  Salir a correr de madrugada escuchando la disc...  31338424770232321
# 1237995    TL dipenuhi #Anaktengahan dari si @rontongsayur  31338428238929921
# 1237996  Win a $25 ToysRUs Gift Card! Retweet this and ...  31338440834416640
# 1237997  RT @bibi_naa: @mantsekev Hmmm..biz ov me small...  31338455124414464
# 1237998             klaar voor de film! #laatmaarebeginnen  31338467522781184
# 1237999  Thank you for make my day better than yesterda...  31338481456259073
# 1238000  RNN: عاجل || تم توقيف احمد عز من مطار القاهرة ...  31338484014780416
# 1238001  From Nothin' On You in the toilet to #JP6foot7...  31338498678063104
# 1238002  I want your everything as long as it's free .....  31331190208208896
# 1238003  I just took "Whick MB is your #1 Boy....?" and...  31338509352566784
# 1238004         #JP6foot7Remix is best song I ever listen.  31338511562969088
# 1238005                 Praia de Ipanema. #VEMTODOMUNDO :*  31338514142461952
# 1238006  @Criis_6 Yeaaah! :D @LadyGaGa #WeCantWaitForBo...  31338527471968257
# 1238007  [コロプラ:大津地域でブリを手に入れました] #colopl_msgブリのお助けありがとうご...  31338532479959040
# 1238008   今日これだー ( #vanitalk live at http://ustre.am/95GE)  31338539706744832
# 1238009  【マイリスト】【ニコカラ】最速最高シャッターガール【On Vocal】 http://nic...  31338544865742848
# 1238010  Cebol RT @FaktanyaAdalah: #questionoftheday ap...  31338552696504321
# 1238011  i just uploading some pics that i took by my p...  31338565166178304
# 1238012                  Ever been up at 5 am? #notthemove  31338565212307456
# 1238013                                    #Np : Let Me In  31338565786931200
# 1238014  @GodGiven35 my roomie had every room in the be...  31338566202171392
# 1238015  Manusia itu gak pernah puas,berusahlah untuk t...  31338570593603584
# 1238016  @RedVYJ #twkrs 헐- 모르셨음둥? 오늘 생일파티 하는 새카망냥탱이랑 동갑...  31338576457244672
# 1238017                Redelijk hard aant chille #chilling  31338593054105600
# 1238018   @SarahLollipop @Elyszee thanks for the #ff's n_n  31338594358534145
# 1238019  @BRIDGETTEMUSIC #CELEBRITYSUNDAYS @ #ICON star...  31263628577472512
#
#                         id                      created_at  retweeted  \
# 0        31334887931777024  Sat Jan 29 12:56:34 +0000 2011      False
# 1        31334648130830336  Sat Jan 29 12:55:36 +0000 2011       True
# 2        31334897025024000  Sat Jan 29 12:56:36 +0000 2011      False
# 3        31334903031267328  Sat Jan 29 12:56:37 +0000 2011      False
# 4        31334401195380736  Sat Jan 29 12:54:38 +0000 2011       True
# 5        31334910400663552  Sat Jan 29 12:56:39 +0000 2011      False
# 6        31334915085697024  Sat Jan 29 12:56:40 +0000 2011       True
# 7        31334919284195328  Sat Jan 29 12:56:41 +0000 2011      False
# 8        31334930269081601  Sat Jan 29 12:56:44 +0000 2011       True
# 9        31334948820484096  Sat Jan 29 12:56:48 +0000 2011      False
# 10       31334954814148608  Sat Jan 29 12:56:50 +0000 2011      False
# 11       31334956114378752  Sat Jan 29 12:56:50 +0000 2011      False
# 12       31334965459292160  Sat Jan 29 12:56:52 +0000 2011       True
# 13       31334971327127553  Sat Jan 29 12:56:53 +0000 2011      False
# 14       31334972828680192  Sat Jan 29 12:56:54 +0000 2011       True
# 15       31334974913249280  Sat Jan 29 12:56:54 +0000 2011      False
# 16       31334978520350720  Sat Jan 29 12:56:55 +0000 2011      False
# 17       31334350448496640  Sat Jan 29 12:54:25 +0000 2011       True
# 18       31334993997340672  Sat Jan 29 12:56:59 +0000 2011      False
# 19       31334998996946944  Sat Jan 29 12:57:00 +0000 2011      False
# 20       31335002142670850  Sat Jan 29 12:57:01 +0000 2011      False
# 21       31335009109417984  Sat Jan 29 12:57:03 +0000 2011      False
# 22       31335013173698560  Sat Jan 29 12:57:03 +0000 2011      False
# 23       31335016340389888  Sat Jan 29 12:57:04 +0000 2011      False
# 24       31335018622095361  Sat Jan 29 12:57:05 +0000 2011      False
# 25       31335018781474816  Sat Jan 29 12:57:05 +0000 2011      False
# 26       31335030374535168  Sat Jan 29 12:57:08 +0000 2011      False
# 27       31335032371027968  Sat Jan 29 12:57:08 +0000 2011      False
# 28       31335041158094848  Sat Jan 29 12:57:10 +0000 2011      False
# 29       31335041766260736  Sat Jan 29 12:57:10 +0000 2011      False
# ...                    ...                             ...        ...
# 1237990  31338398736195584  Sat Jan 29 13:10:31 +0000 2011      False
# 1237991  31338400309055488  Sat Jan 29 13:10:31 +0000 2011      False
# 1237992  31338416842997760  Sat Jan 29 13:10:35 +0000 2011      False
# 1237993  31338421284773888  Sat Jan 29 13:10:36 +0000 2011       True
# 1237994  31338424770232321  Sat Jan 29 13:10:37 +0000 2011      False
# 1237995  31338428238929921  Sat Jan 29 13:10:38 +0000 2011      False
# 1237996  31338440834416640  Sat Jan 29 13:10:41 +0000 2011      False
# 1237997  31338455124414464  Sat Jan 29 13:10:44 +0000 2011      False
# 1237998  31338467522781184  Sat Jan 29 13:10:47 +0000 2011      False
# 1237999  31338481456259073  Sat Jan 29 13:10:50 +0000 2011       True
# 1238000  31338484014780416  Sat Jan 29 13:10:51 +0000 2011      False
# 1238001  31338498678063104  Sat Jan 29 13:10:54 +0000 2011      False
# 1238002  31331190208208896  Sat Jan 29 12:41:52 +0000 2011       True
# 1238003  31338509352566784  Sat Jan 29 13:10:57 +0000 2011      False
# 1238004  31338511562969088  Sat Jan 29 13:10:58 +0000 2011      False
# 1238005  31338514142461952  Sat Jan 29 13:10:58 +0000 2011      False
# 1238006  31338527471968257  Sat Jan 29 13:11:01 +0000 2011       True
# 1238007  31338532479959040  Sat Jan 29 13:11:03 +0000 2011      False
# 1238008  31338539706744832  Sat Jan 29 13:11:04 +0000 2011      False
# 1238009  31338544865742848  Sat Jan 29 13:11:05 +0000 2011      False
# 1238010  31338552696504321  Sat Jan 29 13:11:07 +0000 2011      False
# 1238011  31338565166178304  Sat Jan 29 13:11:10 +0000 2011      False
# 1238012  31338565212307456  Sat Jan 29 13:11:10 +0000 2011      False
# 1238013  31338565786931200  Sat Jan 29 13:11:10 +0000 2011      False
# 1238014  31338566202171392  Sat Jan 29 13:11:11 +0000 2011      False
# 1238015  31338570593603584  Sat Jan 29 13:11:12 +0000 2011      False
# 1238016  31338576457244672  Sat Jan 29 13:11:13 +0000 2011      False
# 1238017  31338593054105600  Sat Jan 29 13:11:17 +0000 2011      False
# 1238018  31338594358534145  Sat Jan 29 13:11:17 +0000 2011      False
# 1238019  31263628577472512  Sat Jan 29 08:13:24 +0000 2011       True
#
#          retweet_count  favorited       requested_id  \
# 0                    0      False  31334887931777024
# 1                   34       True  31334894172901376
# 2                    0      False  31334897025024000
# 3                    0      False  31334903031267328
# 4                   18       True  31334906613202944
# 5                    0      False  31334910400663552
# 6                    2      False  31334915085697024
# 7                    0      False  31334919284195328
# 8                   19       True  31334930269081601
# 9                    0      False  31334948820484096
# 10                   0      False  31334954814148608
# 11                   0      False  31334956114378752
# 12                   2       True  31334965459292160
# 13                   0      False  31334971327127553
# 14                   5       True  31334972828680192
# 15                   0      False  31334974913249280
# 16                   0      False  31334978520350720
# 17                   1      False  31334992344776704
# 18                   0      False  31334993997340672
# 19                   0      False  31334998996946944
# 20                   0      False  31335002142670850
# 21                   0      False  31335009109417984
# 22                   0      False  31335013173698560
# 23                   0      False  31335016340389888
# 24                   0      False  31335018622095361
# 25                   0      False  31335018781474816
# 26                   0      False  31335030374535168
# 27                   0      False  31335032371027968
# 28                   0      False  31335041158094848
# 29                   0      False  31335041766260736
# ...                ...        ...                ...
# 1237990              0      False  31338398736195584
# 1237991              0      False  31338400309055488
# 1237992              0      False  31338416842997760
# 1237993              2      False  31338421284773888
# 1237994              0      False  31338424770232321
# 1237995              0      False  31338428238929921
# 1237996              0      False  31338440834416640
# 1237997              0      False  31338455124414464
# 1237998              0      False  31338467522781184
# 1237999              3      False  31338481456259073
# 1238000              0      False  31338484014780416
# 1238001              0      False  31338498678063104
# 1238002              3      False  31338503572824064
# 1238003              0      False  31338509352566784
# 1238004              0      False  31338511562969088
# 1238005              0      False  31338514142461952
# 1238006              1      False  31338527471968257
# 1238007              0      False  31338532479959040
# 1238008              0      False  31338539706744832
# 1238009              0      False  31338544865742848
# 1238010              0      False  31338552696504321
# 1238011              0      False  31338565166178304
# 1238012              0      False  31338565212307456
# 1238013              0      False  31338565786931200
# 1238014              0      False  31338566202171392
# 1238015              0      False  31338570593603584
# 1238016              0      False  31338576457244672
# 1238017              0      False  31338593054105600
# 1238018              0      False  31338594358534145
# 1238019              1      False  31338596321468416
#
#                                               text_no_tags    user_id  \
# 0         . Kasi hindi ko masuklian pagmamahal ko sayo. :(   41072582
# 1        RT @she3sha3y: "not baradei, not Ikhwan (broth...   29979814
# 2         kalo sebelum cinta fitri di puter ada lagu in...  129381481
# 3        @1DPaynettes @onedirection to gig in birmingha...   50865325
# 4                 Eunhyuk !!! <3 http://twitpic.com/3uhp5y  136221182
# 5        From me too...RT @archanavijaya: Its sooo nice...  187203939
# 6                              @fernando_x Resumindo: fail   13802992
# 7        Parketpolitie int 750 euro aan openstaande boe...   86923067
# 8        [Update] Shake It Up http://yfrog.com/hsz86hyj...  150212472
# 9                                                 スフィアきた！！  111845155
# 10        中間発表でコメントをもらいます。 ( live at http://ustre.am/sRd2)   99245256
# 11       @Jones_Drew32 man I'm in cali too and I'm up t...   21287456
# 12                   Tapi sampai kapan gue harus nunggu lo  234692084
# 13                               @edgarfong @ontobelli ._.    2928391
# 14       "Quando desisti de perseguir a felicidade, ela...   63281431
# 15       Daleeeeeeeem » "Banyak orang ngaku beriman, pa...  137569580
# 16                                   FSきたあああああああああああああああああ  107882678
# 17       Baterista do U2 é condenado no Brasil. http://...   31971445
# 18                             É isso aii @CHRlSROCK .....  203171610
# 19       RT @chip528_dgs: RT @keraidayo RT @RiinaKw RT ...  160378643
# 20       Start Dealing with Critics and Criticism Right...  159534035
# 21       RT @DonghaeBiased: [Update] Shake It Up http:/...   87936630
# 22       Cell phone service back on in - RIA Novosti fe...  242249961
# 23           "Bringing King to China" http://bit.ly/eErpxw  192012182
# 24       Today @MacMiller wishes that he was with @mach...   48731585
# 25       Comment: Les premiers spectateurs ... http://t...   15045416
# 26                         Phones off, going on the planee  178218746
# 27           Oxford today for game? Bracelet @gabgirlwoah?  128382962
# 28        Retweet & follow @washbag_com for your chance...  111654017
# 29       tak peduli RT @AfgJember: 8 : tak semestinya c...  131769573
# ...                                                    ...        ...
# 1237990   Si LG est meurt financièrement et ayant tant ...  192192055
# 1237991                                       orang tempur  172364979
# 1237992  LOOL adorable XD RT @amna_h: I used to hide be...   80217685
# 1237993  RT Al Jazeera: reports that Ahmad Ezz tried to...  110220042
# 1237994  Salir a correr de madrugada escuchando la disc...  224273951
# 1237995                  TL dipenuhi dari si @rontongsayur  149072167
# 1237996  Win a $25 ToysRUs Gift Card! Retweet this and ...  217418357
# 1237997  RT @bibi_naa: @mantsekev Hmmm..biz ov me small...  149606325
# 1237998                                klaar voor de film!  190250886
# 1237999  Thank you for make my day better than yesterda...  219937457
# 1238000      RNN: عاجل || تم توقيف احمد عز من مطار القاهرة   47616524
# 1238001  From Nothin' On You in the toilet to , its obv...  141048743
# 1238002     I want your everything as long as it's free ..  142656457
# 1238003  I just took "Whick MB is your Boy....?" and go...  194966707
# 1238004                        is best song I ever listen.  141037598
# 1238005                               Praia de Ipanema. :*  111587718
# 1238006                      @Criis_6 Yeaaah! :D @LadyGaGa  234052940
# 1238007                            [コロプラ:大津地域でブリを手に入れました]。  153697075
# 1238008             今日これだー ( live at http://ustre.am/95GE)   99724609
# 1238009  【マイリスト】【ニコカラ】最速最高シャッターガール【On Vocal】 http://nic...  232473442
# 1238010  Cebol RT @FaktanyaAdalah: apa hal yang paling ...  127811270
# 1238011  i just uploading some pics that i took by my p...   64386445
# 1238012                              Ever been up at 5 am?   57822302
# 1238013                                        : Let Me In  138363269
# 1238014  @GodGiven35 my roomie had every room in the be...  187810014
# 1238015  Manusia itu gak pernah puas,berusahlah untuk t...  107919028
# 1238016     @RedVYJ 헐- 모르셨음둥? 오늘 생일파티 하는 새카망냥탱이랑 동갑임둥. ㅋㅋㅋ  229363764
# 1238017                          Redelijk hard aant chille  161357226
# 1238018       @SarahLollipop @Elyszee thanks for the's n_n   50063738
# 1238019  @BRIDGETTEMUSIC @ start THIS SUNDAY! @djblord ...   33435344
#
#         user_screen_name                             tags
# 0             Sassysofia                       [#imSorry]
# 1           monaeltahawy                 [#Jan25, #Egypt]
# 2               kadekdoi    [#buik, #barutahu, #pangling]
# 3         keelybennett12                     [#Twitition]
# 4           eunhaecouple                         [#SS3SG]
# 5              Barodian_                        [#Mumbai]
# 6             pabloprime       [#jogojusto, #saraivawins]
# 7              VeendamNL                       [#Veendam]
# 8          DonghaeBiased                         [#SS3SG]
# 9                8000kei                 [#anispa, #joqr]
# 10                kao_te                  [#bhopal_march]
# 11        ImHeavensDemon                [#westcoastthing]
# 12        CeritaCintaSma                           [#CCS]
# 13               Soulito                         [#Chale]
# 14           MarcioKuhne                   [#marciokuhne]
# 15            HaniAnggra                      [#islamKTP]
# 16             chuuuubet                 [#agqr, #anispa]
# 17           panaticosjp                         [#folha]
# 18          CarolCatalao               [#congratulations]
# 19           hizminmin00              [#LittleBustersfes]
# 20         DanielSharkov                      [#Blogging]
# 21              FAIYFAIY                         [#SS3SG]
# 22       phoneserviceonl                 [#Egypt, #Egypt]
# 23          IdpFilmmaker     [#filmcontracts, #indyfilms]
# 24                 mfcii           [#somewhereintheworld]
# 25             bleumaine                        [#photwi]
# 26               kazhgod                           [#pow]
# 27             TBrown115                          [#Vols]
# 28          MissSarahJay                 [#FreebieFriday]
# 29               AFjambi                [#TebakLaguAfgan]
# ...                  ...                              ...
# 1237990          teekenb                       [#civ2010]
# 1237991           Nabdlj                            [#nw]
# 1237992          AlyaaHz                [#WhenIWasLittle]
# 1237993         MaYousef                        [#jan252]
# 1237994       JOSSrockas                    [#Blackfield]
# 1237995        aurinoptr                  [#Anaktengahan]
# 1237996         winholly                           [#win]
# 1237997          MzD3bby                   [#homewrecker]
# 1237998    JOYCEETALSMAA             [#laatmaarebeginnen]
# 1237999   YoSwaggeQuotes                     [#myownmood]
# 1238000       ashraf9999                 [#jan25, #egypt]
# 1238001            n2135                 [#JP6foot7Remix]
# 1238002    angelamerici_                           [#mms]
# 1238003        fentinova                             [#1]
# 1238004         bunny__s                 [#JP6foot7Remix]
# 1238005            wtrel                  [#VEMTODOMUNDO]
# 1238006     Immasexybaby  [#WeCantWaitForBornThisWayGaGa]
# 1238007   cappermercedes   [#colopl_msgブリのお助けありがとうございました]
# 1238008         nico0927                      [#vanitalk]
# 1238009     nanakaminato                     [#sm6265596]
# 1238010        blonyonnn              [#questionoftheday]
# 1238011          wen1510                         [#ss3sg]
# 1238012          RonWeez                    [#notthemove]
# 1238013     stefaniglist                            [#Np]
# 1238014      lilhaiti214                        [#noorgy]
# 1238015         adintifa                      [#katamama]
# 1238016          bourgom                         [#twkrs]
# 1238017        marciogrp                      [#chilling]
# 1238018  CaptainLuxCanis                            [#ff]
# 1238019     MogulMindset       [#CELEBRITYSUNDAYS, #ICON]
#
# [1238020 rows x 12 columns]

# %%
twitter_text = twitter_data['text_no_tags']
twitter_tags = twitter_data['tags']
len(twitter_text), len(twitter_tags)
# Out:
# (1238020, 1238020)

# %%
twitter_lengths = twitter_text.apply(lambda s: len(s))
print ('Twitter Max Length (characters):', np.max(twitter_lengths))
print ('Twitter 99th Percentile:', np.percentile(twitter_lengths, 99))
print ('Twitter 140 character percentile:', '{:.3f}'.format(stats.percentileofscore(twitter_lengths, 140)))
num_tags = twitter_tags.apply(lambda t: len(t))
print ('Twitter Max Tags:', np.max(num_tags))
# Out:
# Twitter Max Length (characters): 216
# Twitter 99th Percentile: 133.0
# Twitter 140 character percentile: 99.324
# Twitter Max Tags: 10

# %%
# Extract character set

chars = set()
for text in twitter_text:
    chars.update(set(text))
    
chars = sorted(chars)
chars = ['<PAD>'] + chars
print ('{} unique characters.'.format(len(chars)))

char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# 1286 unique characters.

# %%
MAX_LENGTH = 140

# %%
# Vectorize tweets

twitter_X = np.zeros((len(twitter_text), MAX_LENGTH), dtype=np.bool)
for i, text in tqdm(enumerate(twitter_text), total=len(twitter_text)):
    for t, char in enumerate(text):
        if t >= MAX_LENGTH:
            break
        twitter_X[i, t] = char_indices[char]
# Out:
# 100%|██████████| 1238020/1238020 [00:24<00:00, 50959.29it/s]

# %%
# Extract tag set

tag_set = set()
for t in twitter_tags:
    tag_set.update(set(t))
    
tag_set = sorted(tag_set)
print ('{} unique tags.'.format(len(tag_set)))

tag_indices = dict((t, i) for i, t in enumerate(tag_set))
indices_tag = dict((i, t) for i, t in enumerate(tag_set))
# Out:
# 748 unique tags.

# %%
# Vectorize tags

twitter_y = np.zeros((len(twitter_tags), len(tag_set)), dtype=np.bool)
for i, tags in tqdm(enumerate(twitter_tags), total=len(twitter_tags)):
    for tag in tags:
        twitter_y[i, tag_indices[tag]] = 1
# Out:
# 100%|██████████| 1238020/1238020 [00:00<00:00, 1302916.64it/s]

# %%
sss = ShuffleSplit(n_splits=1, random_state=12345)

# Create X and y matricies
for train_idx, test_idx in sss.split(twitter_X, twitter_y):
    train_X, test_X = twitter_X[train_idx], twitter_X[test_idx]
    train_y, test_y = twitter_y[train_idx], twitter_y[test_idx]
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((1114218, 140), (1114218, 748), (123802, 140), (123802, 748))

# %% [markdown]
# # Build Model

# %% [markdown]
# ## BiLSTM Baseline

# %%
model = Sequential()
model.add(Embedding(len(chars) + 1,
                    64,
                    input_length=MAX_LENGTH,
                    trainable=True,
                    mask_zero=True))
model.add(Bidirectional(LSTM(128)))
model.add(Dropout(.5))
model.add(Dense(len(tag_set), activation='softmax'))
print (model.output_shape)
# Out:
# (None, 748)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['categorical_accuracy'])

# %%
filepath="./weights.twitter.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
early_stop = EarlyStopping(monitor='val_categorical_accuracy', patience=3)
callbacks_list = [checkpoint, early_stop]

# %%
model.fit(train_X,
              train_y,
              validation_data=(test_X, test_y),
              shuffle=True,
              batch_size=32,
              epochs=10,
              verbose=0,
              callbacks=callbacks_list)

send_text('BiLSTM Baseline Training complete!')
# Out:
# Epoch 00000: val_categorical_accuracy improved from -inf to 0.16518, saving model to ./weights.twitter.best.hdf5
# Epoch 00001: val_categorical_accuracy did not improve
# Epoch 00002: val_categorical_accuracy improved from 0.16518 to 0.17534, saving model to ./weights.twitter.best.hdf5
# Epoch 00003: val_categorical_accuracy improved from 0.17534 to 0.17878, saving model to ./weights.twitter.best.hdf5
# Epoch 00004: val_categorical_accuracy did not improve
# Epoch 00005: val_categorical_accuracy did not improve
# Epoch 00006: val_categorical_accuracy improved from 0.17878 to 0.18272, saving model to ./weights.twitter.best.hdf5
# Epoch 00007: val_categorical_accuracy did not improve
# Epoch 00008: val_categorical_accuracy did not improve
# Epoch 00009: val_categorical_accuracy did not improve
# Messsage sent.

# %%
model.load_weights('./weights.twitter.best.hdf5')

# %%
pred = model.predict(test_X)
send_text('DONE making predictions.')
# Out:
# Messsage sent.

# %%
p = np.argmax(pred, axis=1)
y = np.argmax(test_y, axis=1)
p.shape, y.shape
# Out:
# ((123802,), (123802,))

# %%
accuracy_score(p, y)
# Out:
# 0.18271918062713041

# %%
pre_count = 0

for i, p in enumerate(pred):
    args = np.argsort(p)[::-1]
    if test_y[i][args[0]] == 1.:
        pre_count += 1

pre_count / pred.shape[0]
# Out:
# 0.2033408184035799

# %%
tag_counts = defaultdict(lambda: 0)

for y in test_y:
    targets = np.nonzero(y)[0]
    #print (targets)
    for t in targets:
        tag_counts[t] += 1
        
freq_tags = set()
for k, v in tag_counts.items():
    if v > 19000:
        freq_tags.add(k)
        
len(freq_tags)
#indices_tag[299]
#len(tag_counts)
# Out:
# 0

# %%
mean_ranks = []

for i, p in enumerate(pred):
    ranks = []
    args = np.argsort(p)[::-1]
    #print (p[args], args)
    #break
    targets = np.nonzero(test_y[i])[0]
    for t in targets:
        ranks.append(np.nonzero(args == t)[0][0])
    mean_ranks.extend(ranks)

np.mean(np.asarray(mean_ranks))
# Out:
# 3.8947458528740975

# %%
recalls = []

for i, p in enumerate(pred):
    recall_count = 0
    args = list(np.argsort(p)[::-1][:10])
    targets = np.nonzero(test_y[i])[0]
    if len(targets) == 0:
        continue
    num_tags = len(targets)
    for t in targets:
        if t in args:
            recall_count += 1
    #mean_ranks.append(np.mean(np.asarray(ranks)))
    recalls.append(recall_count / num_tags)

np.mean(np.asarray(recalls))
# Out:
# 0.93907085507503907
